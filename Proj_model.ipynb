# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df=pd.read_csv('Activity_Tracker.csv')
df
# Out:
#         User_ID  Calories  Gender  Age  Height  Weight  Duration  Heart_Rate  \
# 0      10001159      76.0  female   67   176.0    74.0      12.0       103.0
# 1      10001607      93.0  female   34   178.0    79.0      19.0        96.0
# 2      10005485      49.0  female   38   178.0     NaN      14.0        82.0
# 3      10005630      36.0  female   39   169.0    66.0       8.0        90.0
# 4      10006441     122.0    male   23   169.0    73.0      25.0       102.0
# ...         ...       ...     ...  ...     ...     ...       ...         ...
# 14995  19999044     129.0  female   25   169.0    66.0      22.0       105.0
# 14996  19999086      42.0  female   31   170.0    69.0       9.0        93.0
# 14997  19999257     112.0    male   21   176.0    75.0      19.0       109.0
# 14998  19999394      42.0  female   36   152.0    54.0      10.0        86.0
# 14999  19999647     152.0    male   29   164.0    67.0      30.0       102.0
#
#        Body_Temp Activity_Type
# ...

# %%
df.isna().sum()
# Out:
# User_ID            0
# Calories           0
# Gender             0
# Age                0
# Height            90
# Weight           105
# Duration           0
# Heart_Rate       300
# Body_Temp        150
# Activity_Type      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'Calories', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Activity_Type'],
#       dtype='object')

# %%
df.head()
# Out:
#     User_ID  Calories  Gender  Age  Height  Weight  Duration  Heart_Rate  \
# 0  10001159      76.0  female   67   176.0    74.0      12.0       103.0
# 1  10001607      93.0  female   34   178.0    79.0      19.0        96.0
# 2  10005485      49.0  female   38   178.0     NaN      14.0        82.0
# 3  10005630      36.0  female   39   169.0    66.0       8.0        90.0
# 4  10006441     122.0    male   23   169.0    73.0      25.0       102.0
#
#    Body_Temp Activity_Type
# 0       39.6       Running
# 1       40.6       Running
# 2       40.5       Walking
# 3       39.6       Running
# 4       40.7       Running

# %%
df.tail()
# Out:
#         User_ID  Calories  Gender  Age  Height  Weight  Duration  Heart_Rate  \
# 14995  19999044     129.0  female   25   169.0    66.0      22.0       105.0
# 14996  19999086      42.0  female   31   170.0    69.0       9.0        93.0
# 14997  19999257     112.0    male   21   176.0    75.0      19.0       109.0
# 14998  19999394      42.0  female   36   152.0    54.0      10.0        86.0
# 14999  19999647     152.0    male   29   164.0    67.0      30.0       102.0
#
#        Body_Temp Activity_Type
# 14995       40.6       Running
# 14996       39.8       Running
# 14997       40.5       Running
# 14998       39.7       Walking
# 14999       41.2       Running

# %%
df.describe()
# Out:
#             User_ID      Calories           Age        Height        Weight  \
# count  1.500000e+04  15000.000000  15000.000000  14910.000000  14895.000000
# mean   1.497736e+07     89.539533     42.789800    174.460630     74.993018
# std    2.872851e+06     62.456978     16.980264     14.245621     15.036782
# min    1.000116e+07      1.000000     20.000000    123.000000     36.000000
# 25%    1.247419e+07     35.000000     28.000000    164.000000     63.000000
# 50%    1.499728e+07     79.000000     39.000000    175.000000     74.000000
# 75%    1.744928e+07    138.000000     56.000000    185.000000     87.000000
# max    1.999965e+07    314.000000     79.000000    222.000000    132.000000
#
#            Duration    Heart_Rate     Body_Temp
# count  15000.000000  14700.000000  14850.000000
# mean      15.530600     95.538367     40.025024
# std        8.319203      9.585140      0.779600
# min        1.000000     67.000000     37.100000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User_ID        15000 non-null  int64
#  1   Calories       15000 non-null  float64
#  2   Gender         15000 non-null  object
#  3   Age            15000 non-null  int64
#  4   Height         14910 non-null  float64
#  5   Weight         14895 non-null  float64
#  6   Duration       15000 non-null  float64
#  7   Heart_Rate     14700 non-null  float64
#  8   Body_Temp      14850 non-null  float64
#  9   Activity_Type  15000 non-null  object
# dtypes: float64(6), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
df1=df['Gender'].value_counts()
plt.bar(df1.index,df1.values)
# Out:
# <BarContainer object of 2 artists>

# %%
df['Calories'].value_counts()
# Out:
# Calories
# 7.0      161
# 13.0     142
# 12.0     137
# 11.0     137
# 17.0     136
#         ...
# 300.0      1
# 258.0      1
# 273.0      1
# 287.0      1
# 253.0      1
# Name: count, Length: 277, dtype: int64

# %%
df=df.drop(['User_ID'],axis=1)
df
# Out:
#        Calories  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0          76.0  female   67   176.0    74.0      12.0       103.0       39.6
# 1          93.0  female   34   178.0    79.0      19.0        96.0       40.6
# 2          49.0  female   38   178.0     NaN      14.0        82.0       40.5
# 3          36.0  female   39   169.0    66.0       8.0        90.0       39.6
# 4         122.0    male   23   169.0    73.0      25.0       102.0       40.7
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995     129.0  female   25   169.0    66.0      22.0       105.0       40.6
# 14996      42.0  female   31   170.0    69.0       9.0        93.0       39.8
# 14997     112.0    male   21   176.0    75.0      19.0       109.0       40.5
# 14998      42.0  female   36   152.0    54.0      10.0        86.0       39.7
# 14999     152.0    male   29   164.0    67.0      30.0       102.0       41.2
#
#       Activity_Type
# ...

# %%
df.isna().sum()
# Out:
# Calories           0
# Gender             0
# Age                0
# Height            90
# Weight           105
# Duration           0
# Heart_Rate       300
# Body_Temp        150
# Activity_Type      0
# dtype: int64

# %%
# from sklearn.impute import KNNImputer
# imputer = KNNImputer(n_neighbors=7)
# df[['Height','Weight','Heart_Rate','Body_Temp']] = imputer.fit_transform(
#     df[['Height','Weight','Heart_Rate','Body_Temp']])

# %%
df.isna().sum()
# Out:
# Calories           0
# Gender             0
# Age                0
# Height            90
# Weight           105
# Duration           0
# Heart_Rate       300
# Body_Temp        150
# Activity_Type      0
# dtype: int64

# %%
df
# Out:
#        Calories  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0          76.0  female   67   176.0    74.0      12.0       103.0       39.6
# 1          93.0  female   34   178.0    79.0      19.0        96.0       40.6
# 2          49.0  female   38   178.0     NaN      14.0        82.0       40.5
# 3          36.0  female   39   169.0    66.0       8.0        90.0       39.6
# 4         122.0    male   23   169.0    73.0      25.0       102.0       40.7
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995     129.0  female   25   169.0    66.0      22.0       105.0       40.6
# 14996      42.0  female   31   170.0    69.0       9.0        93.0       39.8
# 14997     112.0    male   21   176.0    75.0      19.0       109.0       40.5
# 14998      42.0  female   36   152.0    54.0      10.0        86.0       39.7
# 14999     152.0    male   29   164.0    67.0      30.0       102.0       41.2
#
#       Activity_Type
# ...

# %%
df['Mass_Duration'] = df['Weight'] * df['Duration']

# %%
df
# Out:
#        Calories  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0          76.0  female   67   176.0    74.0      12.0       103.0       39.6
# 1          93.0  female   34   178.0    79.0      19.0        96.0       40.6
# 2          49.0  female   38   178.0     NaN      14.0        82.0       40.5
# 3          36.0  female   39   169.0    66.0       8.0        90.0       39.6
# 4         122.0    male   23   169.0    73.0      25.0       102.0       40.7
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995     129.0  female   25   169.0    66.0      22.0       105.0       40.6
# 14996      42.0  female   31   170.0    69.0       9.0        93.0       39.8
# 14997     112.0    male   21   176.0    75.0      19.0       109.0       40.5
# 14998      42.0  female   36   152.0    54.0      10.0        86.0       39.7
# 14999     152.0    male   29   164.0    67.0      30.0       102.0       41.2
#
# ...

# %%
a=df.corr(numeric_only=True)
sns.heatmap(a,annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(y='Body_Temp',data=df)
# Out:
# <Axes: ylabel='Body_Temp'>

# %%
Q1 = df['Body_Temp'].quantile(0.25)
Q3 = df['Body_Temp'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

body_temp = df['Body_Temp'].median()
df.loc[
    (df['Body_Temp'] < lower),
    'Body_Temp'] = body_temp

# %%
sns.boxplot(y='Body_Temp',data=df)
# Out:
# <Axes: ylabel='Body_Temp'>

# %%
sns.boxplot(y='Mass_Duration',data=df)
# Out:
# <Axes: ylabel='Mass_Duration'>

# %%
Q1 = df['Mass_Duration'].quantile(0.25)
Q3 = df['Mass_Duration'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
mass_duration = df['Mass_Duration'].median()
df.loc[(df['Mass_Duration'] > upper),'Mass_Duration'] = mass_duration

# %%
sns.boxplot(y='Mass_Duration',data=df)
# Out:
# <Axes: ylabel='Mass_Duration'>

# %%
df2=pd.get_dummies(df[['Gender','Activity_Type']],drop_first=True,dtype=int)
df2
# Out:
#        Gender_male  Activity_Type_Jogging  Activity_Type_Running  \
# 0                0                      0                      1
# 1                0                      0                      1
# 2                0                      0                      0
# 3                0                      0                      1
# 4                1                      0                      1
# ...            ...                    ...                    ...
# 14995            0                      0                      1
# 14996            0                      0                      1
# 14997            1                      0                      1
# 14998            0                      0                      0
# 14999            1                      0                      1
#
#        Activity_Type_Walking
# 0                          0
# 1                          0
# 2                          1
# 3                          0
# 4                          0
# ...

# %%
dff=pd.concat([df,df2],axis=1)
dff
# Out:
#        Calories  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0          76.0  female   67   176.0    74.0      12.0       103.0       39.6
# 1          93.0  female   34   178.0    79.0      19.0        96.0       40.6
# 2          49.0  female   38   178.0     NaN      14.0        82.0       40.5
# 3          36.0  female   39   169.0    66.0       8.0        90.0       39.6
# 4         122.0    male   23   169.0    73.0      25.0       102.0       40.7
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995     129.0  female   25   169.0    66.0      22.0       105.0       40.6
# 14996      42.0  female   31   170.0    69.0       9.0        93.0       39.8
# 14997     112.0    male   21   176.0    75.0      19.0       109.0       40.5
# 14998      42.0  female   36   152.0    54.0      10.0        86.0       39.7
# 14999     152.0    male   29   164.0    67.0      30.0       102.0       41.2
#
# ...

# %%
dff.isna().sum()
# Out:
# Calories                   0
# Gender                     0
# Age                        0
# Height                    90
# Weight                   105
# Duration                   0
# Heart_Rate               300
# Body_Temp                150
# Activity_Type              0
# Mass_Duration            105
# Gender_male                0
# Activity_Type_Jogging      0
# Activity_Type_Running      0
# Activity_Type_Walking      0
# dtype: int64

# %%
dff=dff.drop(['Gender','Activity_Type'],axis=1)
dff
# Out:
#        Calories  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0          76.0   67   176.0    74.0      12.0       103.0       39.6
# 1          93.0   34   178.0    79.0      19.0        96.0       40.6
# 2          49.0   38   178.0     NaN      14.0        82.0       40.5
# 3          36.0   39   169.0    66.0       8.0        90.0       39.6
# 4         122.0   23   169.0    73.0      25.0       102.0       40.7
# ...         ...  ...     ...     ...       ...         ...        ...
# 14995     129.0   25   169.0    66.0      22.0       105.0       40.6
# 14996      42.0   31   170.0    69.0       9.0        93.0       39.8
# 14997     112.0   21   176.0    75.0      19.0       109.0       40.5
# 14998      42.0   36   152.0    54.0      10.0        86.0       39.7
# 14999     152.0   29   164.0    67.0      30.0       102.0       41.2
#
#        Mass_Duration  Gender_male  Activity_Type_Jogging  \
# 0              888.0            0                      0
# ...

# %%
dff.isna().sum()
# Out:
# Calories                   0
# Age                        0
# Height                    90
# Weight                   105
# Duration                   0
# Heart_Rate               300
# Body_Temp                150
# Mass_Duration            105
# Gender_male                0
# Activity_Type_Jogging      0
# Activity_Type_Running      0
# Activity_Type_Walking      0
# dtype: int64

# %%
x=dff.drop(['Calories'],axis=1)
x
# Out:
#        Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Mass_Duration  \
# 0       67   176.0    74.0      12.0       103.0       39.6          888.0
# 1       34   178.0    79.0      19.0        96.0       40.6         1501.0
# 2       38   178.0     NaN      14.0        82.0       40.5            NaN
# 3       39   169.0    66.0       8.0        90.0       39.6          528.0
# 4       23   169.0    73.0      25.0       102.0       40.7         1825.0
# ...    ...     ...     ...       ...         ...        ...            ...
# 14995   25   169.0    66.0      22.0       105.0       40.6         1452.0
# 14996   31   170.0    69.0       9.0        93.0       39.8          621.0
# 14997   21   176.0    75.0      19.0       109.0       40.5         1425.0
# 14998   36   152.0    54.0      10.0        86.0       39.7          540.0
# 14999   29   164.0    67.0      30.0       102.0       41.2         2010.0
#
#        Gender_male  Activity_Type_Jogging  Activity_Type_Running  \
# ...

# %%
y=dff['Calories']
y
# Out:
# 0         76.0
# 1         93.0
# 2         49.0
# 3         36.0
# 4        122.0
#          ...
# 14995    129.0
# 14996     42.0
# 14997    112.0
# 14998     42.0
# 14999    152.0
# Name: Calories, Length: 15000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
x_train
# Out:
#        Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Mass_Duration  \
# 11797   67   183.0    81.0      29.0       114.0       41.2         2349.0
# 5899    41   153.0    49.0      25.0       110.0       41.2         1225.0
# 9513    40   203.0   104.0      18.0       108.0       40.5         1872.0
# 1572    28   180.0    79.0      28.0       103.0       40.7         2212.0
# 12995   32   158.0    57.0      23.0       101.0       40.6         1311.0
# ...    ...     ...     ...       ...         ...        ...            ...
# 5191    27   192.0    90.0      16.0        88.0       39.8         1440.0
# 13418   22   161.0    58.0      23.0        97.0       40.7         1334.0
# 5390    61   174.0    67.0      18.0        91.0       40.7         1206.0
# 860     21   157.0    57.0       2.0        77.0       40.2          114.0
# 7270    77   161.0    63.0      28.0       106.0       40.9         1764.0
#
#        Gender_male  Activity_Type_Jogging  Activity_Type_Running  \
# ...

# %%
x_test
# Out:
#        Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Mass_Duration  \
# 11499   41     NaN    60.0      28.0       101.0       40.9         1680.0
# 6475    29     NaN    75.0      14.0        95.0       40.1         1050.0
# 13167   70     NaN    86.0       3.0        89.0       38.4          258.0
# 862     31     NaN    87.0      19.0        94.0       40.4         1653.0
# 5970    43     NaN    94.0      25.0       109.0       40.5         2350.0
# ...    ...     ...     ...       ...         ...        ...            ...
# 4217    41   183.0    85.0      29.0         NaN       41.0         2465.0
# 13886   33   168.0    73.0      21.0        99.0       40.6         1533.0
# 10464   42   192.0    89.0      15.0        85.0       40.3         1335.0
# 6902    24   193.0    91.0       5.0        90.0       39.3          455.0
# 4874    50   157.0    62.0       6.0        90.0       39.4          372.0
#
#        Gender_male  Activity_Type_Jogging  Activity_Type_Running  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=7)
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,mean_absolute_percentage_error
knn=KNeighborsRegressor(n_neighbors=7)
dt=DecisionTreeRegressor(max_depth=5,min_samples_split=10,min_samples_leaf=5,random_state=42)
rf=RandomForestRegressor(n_estimators=200,max_depth=5,min_samples_leaf=20,random_state=42)
l=LinearRegression()
lst=[knn,l,dt,rf]

# %%
print('*'*100)
for i in lst:
  print("The model is ",i)
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print(y_pred)
  accuracy=r2_score(y_test,y_pred)*100
  print('Accuracy:',accuracy)
  print("Train R2:", i.score(x_train, y_train))
  print("Test R2:", i.score(x_test, y_test))

  print("MAE:", mean_absolute_error(y_test, y_pred))
  print('MAPE:',mean_absolute_percentage_error(y_test,y_pred))
  print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
  print("R2 Score:", r2_score(y_test, y_pred))
  print('*'*100)
# Out:
# ****************************************************************************************************
# The model is  KNeighborsRegressor(n_neighbors=7)
# [166.42857143  64.          13.71428571 ...  56.42857143  20.57142857
#   31.71428571]
# Accuracy: 99.18379010122386
# Train R2: 0.994136514461878
# Test R2: 0.9918379010122387
# MAE: 3.7107301587301587
# MAPE: 0.07892538470723331
# RMSE: 5.670806011170416
# R2 Score: 0.9918379010122387
# ****************************************************************************************************
# The model is  LinearRegression()
# [159.19777327  68.14709436  35.54454481 ...  70.26666341   3.38531428
#   24.80222896]
# Accuracy: 96.75734674758812
# Train R2: 0.9672829447725795
# Test R2: 0.9675734674758811
# MAE: 8.27717520436306
# MAPE: 0.4150558186873535
# RMSE: 11.303010150667978
# R2 Score: 0.9675734674758811
# ****************************************************************************************************
# ...

# %%
def final_prediction(input_dict):
    df_input = pd.DataFrame([input_dict])
    df_input = pd.get_dummies(df_input, drop_first=True)
    df_input = df_input.reindex(columns=x.columns, fill_value=0)
    df_input = imputer.transform(df_input)
    df_input = scaler.transform(df_input)
    prediction = l.predict(df_input)
    return prediction[0]

# %%
prediction = final_prediction({
    "Gender": "Male",
    "Age": 32,
    "Height": 178,
    "Weight": 70,
    "Duration": 42,
    "Heart_Rate": 125,
    "Body_Temp": 38.8,
    "Avtivity_Type":'Running'
})

print("Predicted Calories:", prediction)
# Out:
# Predicted Calories: 253.14612404830436
# c:\Users\akash\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but KNNImputer was fitted without feature names
#   warnings.warn(
# c:\Users\akash\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
